# %%
from Tokenizer import tokenize
import os
from collections import Counter
from glob import glob
from rich import print
import math

# %%
tokenize("私は日本語を勉強しています")
# Out:
# {'私': 1, '日本': 1, '語': 1, '勉強': 1}

# %%
def detect_hard_words(texts):
    hard_words = []
    for text in texts:
        tokens = tokenize(text)
        for token in tokens:
            hard_words.append(token)
    return hard_words

def parse_srt(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        srt_text = file.read()

    srt_blocks = srt_text.split('\n\n')
    
    sentences = []
    for block in srt_blocks:
        lines = block.split('\n')
        if len(lines) > 2: 
            text = ' '.join(lines[2:]) 
            sentences.append(text.strip())
    
    return sentences

def process_srt_folder():
    hard_words = []
    srt_files = glob(os.path.join("./subtitles", '*.srt'))

    for srt_file in srt_files:
        print(f"[#6699ff]Processing file: {srt_file}[/]")
        sentences = parse_srt(srt_file)
        hard_words.extend(detect_hard_words(sentences))
    
    return hard_words

hard_words = process_srt_folder()
print("[#33ff99]Important Words Detected:[/]")

word_counts = Counter(hard_words).most_common()

def sigmoid(x):
    return 1 / (1 + (math.exp(-x)))

string_to_print = ''
highest_freq = float(word_counts[0][1])
median = float(word_counts[len(word_counts) // 2][1])
for word, freq in word_counts:
    normalized_freq = (float(freq) - median)
    green = sigmoid(normalized_freq)
    red = sigmoid(-normalized_freq)
    blue = sigmoid(-normalized_freq+5)
    string_to_print += f'[b][#{format(int(red * 255), "02x")}{format(int(green * 255), "02x")}{format(int(blue * 255), "02x")}]{word}:[#{format(int((red**0.2) * 255), "02x")}{format(int((green**0.2) * 255), "02x")}{format(int((blue**0.2) * 255), "02x")}]{freq}[/], '

print(string_to_print)
# Out:
# Processing file: ./subtitles\逃げ上手の若君.S01E01.5月22日.WEBRip.Netflix.ja.srt
# Processing file: ./subtitles\逃げ上手の若君.S01E02.やさしいおじさん.WEBRip.Netflix.ja.srt
# Important Words Detected:
# 時行:110, さま:69, 頼重:63, ます:40, 邦時:32, 私:29, 上:29, あなた:27, 宗繁:25, 狩野:24,
# 逃げる:21, まする:20, 狐:20, 次郎:20, 音:19, どの:19, 雫:19, ~:18, ぞ:18, 塩田:18, ハッ:17,
# 何:17, 亜也子:17, 者:15, ンッ:15, 英雄:14, 高:14, 氏:14, 子:14, ハァハァ:13, アア:13,
# 鎌倉:13, 兵:13, 伯父:13, 武士:12, ござる:12, 北条:12, だ:12, お前:12, 敵:12, 新田:12,
# 男性:12, 生きる:11, 未来:11, 兄:11, です:11, 足利:10, 誰:10, 幕府:10, 隠れる:10, 父:10,
# 見る:10, 今:9, えっ:9, 言う:9, って:9, 死ぬ:9, ♪:8, ああ:8, いや:8, 方:8, あの:8, うん:8,
# 父さま:8, わたくし:8, 諏訪:8, 見える:8, 天下:8, 取る:8, a:8, そんな:7, 若い:7, 上手:7, 家:7,
# 主君:7, 清子:7, どこ:7, さあ:7, 分かる:7, 鬼ごっこ:7, 仕える:7, 俺:7, 稽古:6, ンンッ:6,
# くださる:6, 円:6, 喜:6, 手:6, 2人:6, 力:6, 聞く:6, ハァハァハァ:6, すごろく:6, なん:5,
# てる:5, じゃ:5, 高氏:5, 我が:5, 思う:5, 待つ:5, 前:5, 上げる:5, いたす:5, ウッ:5, 国:5, 男:5,
# なぜ:5, 神:5, 全て:5, 追う:5, 五大院:5, ナレーション:4, こそ:4, 時代:4, フゥ:4, くれる:4,
# 若君:4, 行く:4, まいる:4, 君:4, 継ぐ:4, 我:4, けど:4, わ:4, 中:4, 臆病:4, 時:4, 行:4, さす:4,
# 馬:4, 若:4, 笑顔:4, 怪物:4, ウワーッ:4, 目:4, ゆえ:4, 祈祷:4, 気:4, 全部:4, 強い:4, 軍:4,
# 裏切り:4, 皆:4, っ:4, インチキ:4, 滅ぼす:4, なさる:4, 楽しい:4, 来る:4, 出す:4, 知る:4, 実:4,
# 子供:4, はい:4, b:4, しかも:4, 守る:4, 潔い:3, はっ:3, 京:3, いただく:3, 将来:3, まあ:3,
# 摂津:3, 違う:3, 飾り:3, 王:3, 高時:3, 優しい:3, 日:3, ほう:3, 怠惰:3, フフッ:3, うえ:3, 嫌:3,
# 女性:3, いななき:3, 好き:3, いける:3, 信濃:3, 申す:3, 間:3, 登る:3, 神力:3, 必ず:3, 人:3,
# 年:3, 入る:3, 大将:3, 声:3, 逃がす:3, 切る:3, 日本:3, 討つ:3, 師:3, 信ずる:3, 恥:3, 底:3,
# 延びる:3, 殺す:3, もちろん:3, 仲間:3, 続ける:3, 鬼:3, 返す:3, 首:3, 命:3, ー:3, みんな:3,
# 裏切る:3, なんて:3, 貧乏:3, ねえ:3, 鬼畜:3, 敵討ち:3, よろしく:3, 乱世:3, 適応:3, 死:2,
# 生涯:2, 弓:2, 時間:2, すむ:2, ああっ:2, 馬鹿:2, 場合:2, 風:2, 危ない:2, 下りる:2, 笑い声:2,
# する:2, 逃げ足:2, 変わる:2, 後醍醐:2, 乱:2, 鎮める:2, ほうじょう:2, 忠義:2, 活躍:2, フッ:2,
# 跡継ぎ:2, む:2, あら:2, まったく:2, ばかり:2, すぎる:2, 本気:2, 後継:2, つく:2, 早い:2,
# 側室:2, 自慢:2, げ:2, 見つける:2, 家人:2, おおっ:2, アハハハッ:2, 平和:2, 別:2, 町:2,
# どおり:2, 初:2, かかる:2, 神官:2, 失礼:2, 持つ:2, 神聖:2, 怪しい:2, 木:2, 拾える:2, 更に:2,
# どちら:2, 幸せ:2, う~ん:2, 面白い:2, ツッコミ:2, 後:2, 歳:2, すら:2, とても:2, 大:2, 多い:2,
# おーっ:2, 伝令:2, 上がる:2, 向かう:2, 刺さる:2, 押す:2, 最期:2, 領地:2, かくまう:2, こちら:2,
# 一緒:2, ない:2, 地獄:2, のける:2, 泣き声:2, 偽り:2, 討てる:2, 物音:2, 斬る:2, ヘヘッ:2,
# ウワッ:2, こら:2, 生存:2, 本能:2, 才能:2, 大好き:2, 飛来:2, 勝つ:2, 殺し:2, 始まり:2, 滅ぶ:2,
# 共:2, 狙う:2, いざ:2, 様子:2, 大丈夫:2, 顔:2, はず:2, 御子:2, 寝顔:2, どれ:2, ギャーッ:2,
# 遊ぶ:2, 監視:2, 戦う:2, 取れる:2, 自分:2, なぁ:2, 確か:2, 物好き:2, 一体:2, 甥:2, 出世:2,
# 頑張る:1, ちょっと:1, インチキ占い:1, っぽい:1, 褒める:1, ハハハッ:1, 鯛:1,

# %%
import requests
import json

def check_word_in_anki(word: str) -> bool:
    payload = {
        "action": "findNotes",
        "version": 6,
        "params": {
            "query": f'"{word}"'
        }
    }

    response = requests.post("http://localhost:8765", json=payload)
    result = response.json()
    return len(result['result']) > 0


word = "悲しい"
if check_word_in_anki(word):
    print(f"The word '{word}' exists in your Anki decks.")
else:
    print(f"The word '{word}' does not exist in your Anki decks.")
# Out:
# The word '悲しい' exists in your Anki decks.

# %%
import math
def detect_hard_words(texts, hard_words_list):
    hard_words = []
    for text in texts:
        tokens = tokenize(text)
        for token in tokens:
            if token not in hard_words_list:
                hard_words.append(token)
    return hard_words

def parse_srt(file_path):
    """
    Parses an SRT file and extracts the text content.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        srt_text = file.read()

    srt_blocks = srt_text.split('\n\n')
    
    sentences = []
    for block in srt_blocks:
        lines = block.split('\n')
        if len(lines) > 2: 
            text = ' '.join(lines[2:]) 
            sentences.append(text.strip())
    
    return sentences

def process_srt_folder(known_words):
    hard_words = []
    srt_files = glob(os.path.join("./subtitles", '*.srt'))

    for srt_file in srt_files:
        print(f"Processing file: {srt_file}")
        sentences = parse_srt(srt_file)
        hard_words.extend(detect_hard_words(sentences, known_words))
    
    return hard_words


hard_words = process_srt_folder(known_words)
print("[#33ff99]Important Words Detected:[/]")

word_counts = Counter(hard_words).most_common()

def sigmoid(x):
    return 1 / (1 + (math.exp(-x)))

string_to_print = ''
highest_freq = float(word_counts[0][1])
median = float(word_counts[len(word_counts) // 2][1])
for word, freq in word_counts:
    normalized_freq = (float(freq) - median)
    green = sigmoid(normalized_freq)
    red = sigmoid(-normalized_freq)
    blue = sigmoid(-normalized_freq+5)
    string_to_print += f'[b][#{format(int(red * 255), "02x")}{format(int(green * 255), "02x")}{format(int(blue * 255), "02x")}]{word}:[#{format(int((red**0.2) * 255), "02x")}{format(int((green**0.2) * 255), "02x")}{format(int((blue**0.2) * 255), "02x")}]{freq}[/], '

print(string_to_print)

# %%
import spacy
from collections import Counter


nlp = spacy.load('ja_core_news_sm')

def tokenize_and_lemmatize(text):

    doc = nlp(text)
    return [token.lemma_ for token in doc if not token.is_punct and not token.is_stop]

def detect_hard_words(texts, hard_words_list):
    hard_words = []
    for text in texts:

        tokens = tokenize_and_lemmatize(text)
        for token in tokens:
            if token not in hard_words_list:
                hard_words.append(token)
    return hard_words

def main():

    subtitle_strings = [
        "日本語を一番好きな言語"
    ]
    
    
    known_words = set([
        "する", "です", "ます", "行く", "見る", "分かる", "食べる", 
        "天気", "映画", "レストラン", "勉強", "楽しい", "提供", "美味しい", "語"
    ])
    

    hard_words = detect_hard_words(subtitle_strings, known_words)
    print("[#33ff99]Hard Words Detected:[/]")
    dict = Counter(hard_words)
    highestFreq = float(dict[next(key for key in dict)])
    stringToPrint = ''
    for word in dict:
        freq = dict[word]
        green = (float(freq)/highestFreq)
        red = 1-(float(freq)/highestFreq)
        stringToPrint += (f'[#{format(int(red*255), "02x")}{format(int(green*255), "02x")}ff]{word}[/]\n')
    print(stringToPrint)

if __name__ == "__main__":
    main()
